# %% [markdown]
# <h1>Abandono y finalizacion de estudiantes universitarios</h1>

# %% [markdown]
# En este proyecto se estará analizando un dataset extraido de <a href="https://www.kaggle.com/datasets/marouandaghmoumi/dropout-and-success-student-data-analysis?resource=download">https://www.kaggle.com/datasets/marouandaghmoumi/dropout-and-success-student-data-analysis?resource=download</a>.
# El conjunto de datos incluye información conocida en el momento de la matrícula del estudiante: trayectoria académica, datos demográficos y factores socioeconómicos.

# %% [markdown]
# <details><summary>Explicación numérica de las caracteristicas definidas por el creador del dataset</summary>
#
# - **Estado civil:** Variable categórica que indica el estado civil del individuo. (1 - soltero, 2 - casado, 3 - viudo, 4 - divorciado, 5 - unión de hecho, 6 - separado legalmente)
#
# - **Modo de solicitud:** Variable categórica que indica el modo de solicitud. (1 - 1ª fase - contingente general, 2 - Ordenanza nº 612/93, 5 - 1ª fase - contingente especial (Isla de Azores), 7 - Titulares de otros cursos superiores, 10 - Ordenanza nº 854-B/99, 15 - Estudiante internacional (licenciatura), 16 - 1ª fase - contingente especial (Isla de Madeira), 17 - 2ª fase - contingente general, 18 - 3ª fase - contingente general, 26 - Ordenanza nº 533-A/99, ítem b2) (Plan Diferente), 27 - Ordenanza nº 533-A/99, ítem b3 (Otra Institución), 39 - Mayores de 23 años, 42 - Transferencia, 43 - Cambio de curso, 44 - Titulares de diploma de especialización tecnológica, 51 - Cambio de institución/curso, 53 - Titulares de diploma de ciclo corto, 57 - Cambio de institución/curso (Internacional)).
#
# - **Orden de solicitud:** Variable numérica que indica el orden de solicitud. (entre 0 - primera opción; y 9 - última opción).
#
# - **Curso:** Variable categórica que indica el curso elegido. (33 - Tecnologías de Producción de Biocombustibles, 171 - Animación y Diseño Multimedia, 8014 - Servicio Social (turno de noche), 9003 - Agronomía, 9070 - Diseño de Comunicación, 9085 - Enfermería Veterinaria, 9119 - Ingeniería Informática, 9130 - Equinicultura, 9147 - Gestión, 9238 - Servicio Social, 9254 - Turismo, 9500 - Enfermería, 9556 - Higiene Oral, 9670 - Gestión y Dirección de Publicidad y Marketing, 9773 - Periodismo y Comunicación, 9853 - Educación Básica, 9991 - Gestión (turno de noche)).
#
# - **Asistencia nocturna:** Variable binaria que indica si el individuo asiste a clases durante el día o la noche. (1 para diurno, 0 para nocturno).
#
# - **Calificación previa:** Variable numérica que indica el nivel de la calificación previa. (1 - Educación Secundaria, 2 - Educación Superior - licenciatura, 3 - Educación Superior - grado, 4 - Educación Superior - máster, 5 - Educación Superior - doctorado, 6 - Frecuencia de educación superior, 9 - 12º año de escolaridad - no completado, 10 - 11º año de escolaridad - no completado, 12 - Otro - 11º año de escolaridad, 14 - 10º año de escolaridad, 15 - 10º año de escolaridad - no completado, 19 - Educación Básica 3º ciclo (9º/10º/11º año) o equivalente, 38 - Educación Básica 2º ciclo (6º/7º/8º año) o equivalente, 39 - Curso de especialización tecnológica, 40 - Educación Superior - grado (1º ciclo), 42 - Curso técnico superior profesional, 43 - Educación Superior - máster (2º ciclo)).
Técnicos de nivel intermedio en ciencias e ingeniería y profesiones afines, 132 - Técnicos y profesionales de nivel intermedio de la salud, 134 - Técnicos de nivel intermedio en servicios legales, sociales, deportivos, culturales y similares, 135 - Técnicos de tecnologías de la información y comunicación, 141 - Trabajadores de oficina, secretarios en general y operadores de procesamiento de datos, 143 - Operadores de datos, contables, estadísticos, servicios financieros y relacionados con registros, 144 - Otro personal de apoyo administrativo, 151 - Trabajadores de servicios personales, 152 - Vendedores, 153 - Trabajade cuidado personal

# %%
import pandas as pd
import numpy as np

# %%
filepath = r"C:\Users\anton\OneDrive\Documentos\Antoni\student_data.csv"
df = pd.read_csv(filepath, sep=';')

# %% [markdown]
# Aqui tenemos el dataset

# %%
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                 8                  5       2
# 1                  1                 6                  1      11
# 2                  1                 1                  5       5
# 3                  1                 8                  2      15
# 4                  2                12                  1       3
# ...              ...               ...                ...     ...
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       evening attendance  Previous qualification  Nacionality  \
# 0                      1                       1            1
# ...

# %%
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571          6.886980           1.727848     9.899186
# std          0.605747          5.298964           1.313793     4.331792
# min          1.000000          1.000000           0.000000     1.000000
# 25%          1.000000          1.000000           1.000000     6.000000
# 50%          1.000000          8.000000           1.000000    10.000000
# 75%          1.000000         12.000000           2.000000    13.000000
# max          6.000000         18.000000           9.000000    17.000000
#
#        evening attendance  Previous qualification  Nacionality  \
# count         4424.000000             4424.000000  4424.000000
# mean             0.890823                2.531420     1.254521
# std              0.311897                3.963707     1.748447
# min              0.000000                1.000000     1.000000
# ...

# %% [markdown]
# De esta manera vamos a verificar que no hayan registros con datos vacios, si este es el caso, debemos eliminar dichos registros o reemplazarlos.

# %%
missing_data = df.isnull()
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Marital status
# Marital status
# False    4424
# Name: count, dtype: int64
#
# Application mode
# Application mode
# False    4424
# Name: count, dtype: int64
#
# Application order
# Application order
# False    4424
# Name: count, dtype: int64
#
# Course
# Course
# False    4424
# Name: count, dtype: int64
#
# evening attendance
# evening attendance
# False    4424
# Name: count, dtype: int64
#
# Previous qualification
# Previous qualification
# False    4424
# Name: count, dtype: int64
#
# Nacionality
# Nacionality
# False    4424
# Name: count, dtype: int64
#
# Mother's qualification
# Mother's qualification
# False    4424
# Name: count, dtype: int64
#
# Father's qualification
# Father's qualification
# False    4424
# Name: count, dtype: int64
#
# Mother's occupation
# Mother's occupation
# False    4424
# Name: count, dtype: int64
#
# Father's occupation
# Father's occupation
# False    4424
# Name: count, dtype: int64
#
# Displaced
# Displaced
# False    4424
# ...

# %% [markdown]
# Aqui confirmamos que no hay un solo registro que no este completo. La variable que estaré tomando en cuenta para este análisis será la columna de 'Output' que muestra el resultado. Pueden ser tres resultados: abandonada, graduado, en curso. Las convertire en numeros para realizar un analisis de correlacion.

# %%
print(df['Output'].unique())
# Out:
# ['Dropout' 'Graduate' 'Enrolled']

# %%
resultados = {'Dropout':0,'Enrolled':1,'Graduate':2}
df['Output'] = df['Output'].replace(resultados)
df
# Out:
#       Marital status  Application mode  Application order  Course  \
# 0                  1                 8                  5       2
# 1                  1                 6                  1      11
# 2                  1                 1                  5       5
# 3                  1                 8                  2      15
# 4                  2                12                  1       3
# ...              ...               ...                ...     ...
# 4419               1                 1                  6      15
# 4420               1                 1                  2      15
# 4421               1                 1                  1      12
# 4422               1                 1                  1       9
# 4423               1                 5                  1      15
#
#       evening attendance  Previous qualification  Nacionality  \
# 0                      1                       1            1
# ...

# %%
correlaciones = df.corrwith(df['Output'])
print(correlaciones)
# Out:
# Marital status                                   -0.089804
# Application mode                                 -0.212025
# Application order                                 0.089791
# Course                                            0.007841
# evening attendance                                0.075107
# Previous qualification                           -0.091365
# Nacionality                                      -0.004740
# Mother's qualification                           -0.038346
# Father's qualification                            0.000329
# Mother's occupation                               0.048424
# Father's occupation                               0.051702
# Displaced                                         0.113986
# Educational special needs                        -0.007353
# Debtor                                           -0.240999
# Tuition fees up to date                           0.409827
# Gender                                           -0.229270
# ...
